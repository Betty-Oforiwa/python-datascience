# %%
import numpy as np
import csv

with open('AAPL-2017.csv', newline='') as f:
    reader= csv.DictReader(f)
    newArray = np.empty((0,4))
    for row in reader:
        oneRow = np.array([[row['High'], row['Low'],row['Close'], row['Open']]])
        newArray = np.append(newArray,oneRow,axis=0)
        
newArray = np.delete(newArray,7,axis=0)
print(newArray.shape)
        #newArray =np.Arange( )
        #print(newArray)
        #print(np.shape(newArray))
        #print(newArray.ndim)
       # print(type(newArray))
# Out:
# (250, 4)

# %%
newArray = np.arange(116.33002,141.11001,116.33002, int)
print(newArray)
# Out:
# [116]

# %%
newArray = np.array([116.33002,141.11001,116.33002])
print (newArray.shape)
# Out:
# (3,)

# %%
import numpy as np
import csv

with open('AAPL-2017.csv', newline='') as f:
    reader= csv.DictReader(f)
    data = np.empty((0,6))
    for row in reader:
        oneRow = np.array([[row['High'], row['Low'],row['Close'], row['Open'], row['Adj Close'], row['Volume'] ]])
        data = np.append(data,oneRow,axis=0)
      
    

data = np.delete(data,7,axis=0)
#print(data.shape)
#print(np.shape(data))
#print(data.ndim)
#print(type(data))

# %%
with open("AAPL-2016.csv", newline='') as filename:
    reader = csv.DictReader(filename)
    people = np.empty((0,6))
    for row in reader:
        oneRow = np.array([[row['High'], row['Low'],row['Close'], row['Open'], row['Adj Close'], row['Volume'] ]])
        people = np.append(people,oneRow,axis=0)
print(people.shape)
# Out:
# (250, 6)

# %%
Vol = people[:, 5]
print(f"2016\n{Vol}")
vol1 = data[:, 5]
#vol1
print('_'*100)
print("2017 \n",vol1)
# Out:
# 2016
# ['67649400' '55791000' '68457400' '81094400' '70798000' '49739400'
#  '49154200' '62439600' '63170100' '79010000' '53087700' '72334400'
#  '52161500' '65800500' '51794500' '75077000' '133369700' '55678800'
#  '64416500' '40943500' '37357200' '45964300' '46471700' '46418100'
#  '54021400' '44331200' '42343600' '50074700' '40351400' '49057900'
#  '44863200' '39021000' '35374200' '34280800' '31942600' '36255700'
#  '27582700' '28991100' '35216300' '50407100' '33169600' '36955700'
#  '46055100' '35828900' '31561900' '27201700' '33513600' '27408200'
#  '25076100' '40067700' '38303500' '34420700' '44205200' '35502700'
#  '32444400' '25703500' '26133000' '19411400' '31190100' '45601100'
#  '25888400' '25874000' '37356200' '26578700' '26404100' '31801900'
#  '23581700' '29407500' '27232300' '33257300' '25473900' '46939000'
#  '60834000' '32384900' '30611000' '31552500' '33683100' '28031600'
#  '56016200' '114602100' '82242700' '68531500' '48160100' '56831300'
# ...

# %%
Vol = Vol.astype(np.int32)
vol1 = vol1.astype(np.int32)
np.sum([Vol,vol1], axis=1)

#print(Vol)
#print(vol1)
# Out:
# array([ 1045061108, -1806594592])

# %%
Vol = Vol.astype(np.int32)
vol1 = vol1.astype(np.int32)
# np.sum([Vol - vol1], axis=1)
change = Vol - vol1
change
# Out:
# array([ 38867500,  34672900,  46263800,  49342500,  37236100,  25277300,
#         21565600,  36327700,  28730300,  55297000,  27490400,  39736500,
#         30111300,  42589500,  19416900,  48739400, 112806800,  25301300,
#         15215500, -71041500,   3646800,  21457000,  19625800,   8234300,
#         31017300,  15981300,  22278100,  27039300,   7125200,  13434800,
#         22278600,  16822800,  10867000,  13443900,  11154400,  14479100,
#          7325300,   5508200,  -1198300,  24196100,  12061500,  15205700,
#         28608800,  17121700,   9406000,   7588900,  16091900,  12099100,
#          -615700,  20835700,  -5581500,  12878700,   4675300,   9642500,
#         12098100,   3307900,   2557900, -13963400,   2000100,  24393800,
#          6226700,   5888300,  17464800,  -1139200,   5255100,  15129700,
#          4648300,   -971900,   6882300,  15434400,   8891800,  32241500,
#         43505600,   9065300,  13290100,  14418200,  14811600,   7990400,
# ...

# %%
change[1]
np.set_printoptions(formatter={'float': '{: 6.2f}'.format})

# %%
import pandas as pd

# %%
Appl = pd.read_csv('AAPL-2016.csv')
Appl.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-01-04  102.610001  105.370003  102.000000  105.349998  100.274513
# 1  2016-01-05  105.750000  105.849998  102.410004  102.709999   97.761681
# 2  2016-01-06  100.559998  102.370003   99.870003  100.699997   95.848511
# 3  2016-01-07   98.680000  100.129997   96.430000   96.449997   91.803276
# 4  2016-01-08   98.550003   99.110001   96.760002   96.959999   92.288696
#
#      Volume
# 0  67649400
# 1  55791000
# 2  68457400
# 3  81094400
# 4  70798000

# %%
Date = Appl['Date']
Date
# Out:
# 0      2016-01-04
# 1      2016-01-05
# 2      2016-01-06
# 3      2016-01-07
# 4      2016-01-08
#           ...
# 245    2016-12-21
# 246    2016-12-22
# 247    2016-12-23
# 248    2016-12-27
# 249    2016-12-28
# Name: Date, Length: 250, dtype: object

# %%
Volume = Appl['Volume']
Volume
# Out:
# 0      67649400
# 1      55791000
# 2      68457400
# 3      81094400
# 4      70798000
#          ...
# 245    23783200
# 246    26085900
# 247    14249500
# 248    18296900
# 249    20905900
# Name: Volume, Length: 250, dtype: int64

# %%
Volume = np.array(Volume)
Date = np.array(Date)

# %%
import numpy as np
import csv

with open('AAPL-2017.csv', newline='') as f:
    reader= csv.DictReader(f)
    data1 = np.empty((0,2))
    for row in reader:
        oneRow = np.array([[row['Date'], row['Volume'] ]])
        data1 = np.append(data1,oneRow,axis=0)
      
    

data1 = np.delete(data1,7,axis=0)
print(data.shape)
print(data1)
#print(np.shape(data))
#print(data.ndim)
#print(type(data))
# Out:
# (0, 2)
# [['2017-01-03' '28781900']
#  ['2017-01-04' '21118100']
#  ['2017-01-05' '22193600']
#  ['2017-01-06' '31751900']
#  ['2017-01-09' '33561900']
#  ['2017-01-10' '24462100']
#  ['2017-01-11' '27588600']
#  ['2017-01-13' '26111900']
#  ['2017-01-17' '34439800']
#  ['2017-01-18' '23713000']
#  ['2017-01-19' '25597300']
#  ['2017-01-20' '32597900']
#  ['2017-01-23' '22050200']
#  ['2017-01-24' '23211000']
#  ['2017-01-25' '32377600']
#  ['2017-01-26' '26337600']
#  ['2017-01-27' '20562900']
#  ['2017-01-30' '30377500']
#  ['2017-01-31' '49201000']
#  ['2017-02-01' '111985000']
#  ['2017-02-02' '33710400']
#  ['2017-02-03' '24507300']
#  ['2017-02-06' '26845900']
#  ['2017-02-07' '38183800']
#  ['2017-02-08' '23004100']
#  ['2017-02-09' '28349900']
#  ['2017-02-10' '20065500']
#  ['2017-02-13' '23035400']
#  ['2017-02-14' '33226200']
#  ['2017-02-15' '35623100']
#  ['2017-02-16' '22584600']
#  ['2017-02-17' '22198200']
#  ['2017-02-21' '24507200']
#  ['2017-02-22' '20836900']
# ...

# %%
import datetime
date = [datetime.datetime.strptime(x,'%Y-%m-%d') for x in data1[:,0]]

# %%
volNew = data1[:, 1]
print(volNew)
# Out:
# ['28781900' '21118100' '22193600' '31751900' '33561900' '24462100'
#  '27588600' '26111900' '34439800' '23713000' '25597300' '32597900'
#  '22050200' '23211000' '32377600' '26337600' '20562900' '30377500'
#  '49201000' '111985000' '33710400' '24507300' '26845900' '38183800'
#  '23004100' '28349900' '20065500' '23035400' '33226200' '35623100'
#  '22584600' '22198200' '24507200' '20836900' '20788200' '21776600'
#  '20257400' '23482900' '36414600' '26211000' '21108100' '21750000'
#  '17446300' '18707200' '22155900' '19612800' '17421700' '15309100'
#  '25691800' '19232000' '43885000' '21542000' '39529900' '25860200'
#  '20346300' '22395600' '23575100' '33374800' '29190000' '21207300'
#  '19661700' '19985700' '19891400' '27717900' '21149000' '16672200'
#  '18933400' '30379400' '20350000' '17822900' '16582100' '14697500'
#  '17328400' '23319600' '17320900' '17134300' '18871500' '20041200'
#  '14246300' '20860400' '33602900' '45352200' '45697000' '23371900'
# ...

# %%
volNew=volNew.astype(np.int32)

# %%
dataPlot=pd.Series(volNew,date)
print(dataPlot)
# Out:
# 2017-01-03    28781900
# 2017-01-04    21118100
# 2017-01-05    22193600
# 2017-01-06    31751900
# 2017-01-09    33561900
#                 ...
# 2017-12-22    16114600
# 2017-12-26    33185500
# 2017-12-27    21498200
# 2017-12-28    16480200
# 2017-12-29    25884400
# Length: 250, dtype: int32

# %%
dataPlot.plot()

# %%
Appl.head(40)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2016-01-04  102.610001  105.370003  102.000000  105.349998  100.274513
# 1   2016-01-05  105.750000  105.849998  102.410004  102.709999   97.761681
# 2   2016-01-06  100.559998  102.370003   99.870003  100.699997   95.848511
# 3   2016-01-07   98.680000  100.129997   96.430000   96.449997   91.803276
# 4   2016-01-08   98.550003   99.110001   96.760002   96.959999   92.288696
# 5   2016-01-11   98.970001   99.059998   97.339996   98.529999   93.783073
# 6   2016-01-12  100.550003  100.690002   98.839996   99.959999   95.144165
# 7   2016-01-13  100.320000  101.190002   97.300003   97.389999   92.697990
# 8   2016-01-14   97.959999  100.480003   95.739998   99.519997   94.725372
# 9   2016-01-15   96.199997   97.709999   95.360001   97.129997   92.450516
# 10  2016-01-19   98.410004   98.650002   95.500000   96.660004   92.003166
# ...

# %%
f40 = Appl.loc[:40, :]

# %%
f40.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(f40['Date'], f40['Volume'])

# %%
Appl1 = pd.read_csv('AAPL-2017.csv')
Appl1.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  115.800003  116.330002  114.760002  116.150002  113.013916
# 1  2017-01-04  115.849998  116.510002  115.750000  116.019997  112.887413
# 2  2017-01-05  115.919998  116.860001  115.809998  116.610001  113.461502
# 3  2017-01-06  116.779999  118.160004  116.470001  117.910004  114.726402
# 4  2017-01-09  117.949997  119.430000  117.940002  118.989998  115.777237
#
#      Volume
# 0  28781900
# 1  21118100
# 2  22193600
# 3  31751900
# 4  33561900

# %%
Date = Appl1['Date']
Date
# Out:
# 0      2017-01-03
# 1      2017-01-04
# 2      2017-01-05
# 3      2017-01-06
# 4      2017-01-09
#           ...
# 246    2017-12-22
# 247    2017-12-26
# 248    2017-12-27
# 249    2017-12-28
# 250    2017-12-29
# Name: Date, Length: 251, dtype: object

# %%
Volume = Appl1['Volume']
Volume
# Out:
# 0      28781900
# 1      21118100
# 2      22193600
# 3      31751900
# 4      33561900
#          ...
# 246    16114600
# 247    33185500
# 248    21498200
# 249    16480200
# 250    25884400
# Name: Volume, Length: 251, dtype: int64

# %%
Appl1.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  115.800003  116.330002  114.760002  116.150002  113.013916
# 1  2017-01-04  115.849998  116.510002  115.750000  116.019997  112.887413
# 2  2017-01-05  115.919998  116.860001  115.809998  116.610001  113.461502
# 3  2017-01-06  116.779999  118.160004  116.470001  117.910004  114.726402
# 4  2017-01-09  117.949997  119.430000  117.940002  118.989998  115.777237
# 5  2017-01-10  118.769997  119.379997  118.300003  119.110001  115.893997
# 6  2017-01-11  118.739998  119.930000  118.599998  119.750000  116.516708
# 7  2017-01-12  118.900002  119.300003  118.209999  119.250000  116.030212
# 8  2017-01-13  119.110001  119.620003  118.809998  119.040001  115.825882
# 9  2017-01-17  118.339996  120.239998  118.220001  120.000000  116.759972
#
#      Volume
# 0  28781900
# 1  21118100
# 2  22193600
# 3  31751900
# 4  33561900
# 5  24462100
# 6  27588600
# 7  27086200
# 8  26111900
# 9  34439800

# %%
f10 = Appl1.loc[:10, :]

# %%
f10.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(f10['Date'], f10['Volume'])

# %%
x1 =f40['Date']
y1 = f40['Volume']
plt.plot(x1,y1, label = '2016')
x2 = f41['Date']
y2 = f41['Volume']
plt.plot2(x2,y2, label = '2017')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-3857362d5bc0> in <module>
#       2 y1 = f40['Volume']
#       3 plt.plot(x1,y1, label = '2016')
# ----> 4 x2 = f41['Date']
#       5 y2 = f41['Volume']
#       6 plt.plot2(x2,y2, label = '2017')
#
# NameError: name 'f41' is not defined
